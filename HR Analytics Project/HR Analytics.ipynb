# %% [markdown]
# # HR Employee

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import pandas as pd

file_path = r'C:\Users\nicho\Downloads\HR Analytics Project\HR-Employee-Attrition.csv'

# Reading the dataset
dataset = pd.read_csv(file_path)
dataset
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
dataset.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
dataset.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
dataset.shape
# Out:
# (1470, 35)

# %%
dataset.info
# Out:
# <bound method DataFrame.info of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
dataset = dataset.drop_duplicates()
dataset = dataset.dropna()
dataset
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# Correlation map for all numeric variables

numeric_df = dataset.select_dtypes(include=['number'])

corr_matrix = numeric_df.corr()


plt.figure(figsize=(20, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Map for Numeric Variables')
plt.show()

# %% [markdown]
# # Visualize the categorical variables

# %%
data_1 = dataset
# Overtime
sns.countplot(data=data_1, x='OverTime')
plt.title('OverTime')
plt.show()

# %%
# Marital Status
sns.countplot(data=data_1, x='MaritalStatus')
plt.title('Marital Status')
plt.show()

# %%
# Job Role
plt.figure(figsize=(10, 5))
sns.countplot(data=data_1, y='JobRole')
plt.title('Job Role')
plt.show()

# %%
# Gender
sns.countplot(data=data_1, x='Gender')
plt.title('Gender')
plt.show()

# %%
# Education Field
plt.figure(figsize=(10,5))
sns.countplot(data=data_1, y = 'EducationField')
plt.title('Education Field')
plt.show()

# %%
# Department
sns.countplot(data =data_1, x='Department')
plt.show()

# %%
# Business Travel
sns.countplot(data= data_1, x='BusinessTravel')
plt.title('Business Travel')
plt.show()

# %%
# Relationship Between Overtime and Age with Gender differentiation
plt.figure(figsize=(12, 6))
sns.boxplot(data=data_1, x='OverTime', y='Age', hue='Gender')
plt.title('Relationship Between Overtime and Age with Gender Differentiation')
plt.show()

# %% [markdown]
# # Plotting numerical variables

# %%
#working years total
plt.figure(figsize=(10, 6))
sns.histplot(data=data_1, x='TotalWorkingYears', bins=10, kde=True)
plt.title('Total Working Years')
plt.show()

# %%
# Education Level
plt.title('Education Level')
sns.histplot(data=data_1, x='Education', bins=10, kde=True)
plt.show()

# %%
# Number of Companies Worked
sns.histplot(data= data_1, x='NumCompaniesWorked', bins=10, kde=True)
plt.title('Number Of Companies Worked')
plt.show()

# %%
# Number of Companies Worked
sns.histplot(data= data_1, x='NumCompaniesWorked', bins=10, kde=True)
plt.title('Number of Companies Worked')
plt.show()

# %%
# Distance From Home
plt.title('Distance From Home')
sns.histplot(data=data_1, x='DistanceFromHome', bins= 10, kde = True)
plt.show()

# %% [markdown]
# # Salary Analysis

# %%
# Monthly Income Distribution
sns.histplot(data=data_1, x='MonthlyIncome', bins = 10, kde=True)
plt.title('Monthly Income Distribution')
plt.show()

# %%
# Salary by Job Role
plt.figure(figsize=(10,5))
sns.boxplot(data=data_1, x='JobRole', y='MonthlyIncome')
plt.title('salary by Job Role')
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# # Employee Satisfaction and Performance

# %%
# Job Satisfaction Distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=data_1, x='JobSatisfaction', bins=10, kde=True)
plt.title('Job Satisfaction Distribution')
plt.show()

# %%
# Performance Rating distribution
sns.histplot(data =dataset, x='PerformanceRating', bins=10, kde=True)
plt.title('Performance Rating Distribution')
plt.show()

# %%
# Employee Tenure
plt.figure(figsize=(10, 6))
sns.histplot(data=data_1, x='YearsAtCompany', bins=10, kde=True)
plt.title('Employee Tenure Distribution')
plt.show()

# %%
# Age Distribution by Department
plt.figure(figsize=(10,6))
sns.boxplot(data= data_1, x='Department', y='Age')
plt.title('Age Distribution by Department')
plt.show()

# %%
# Attrition by Job Role
plt.figure(figsize=(10,5))
sns.countplot(data= data_1, x='JobRole', hue='Attrition')
plt.xticks(rotation=90)
plt.title('Attrition by Job Role')
plt.show()
